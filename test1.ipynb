# %%
import pandas as pd
from pycaret.classification import ClassificationExperiment

# %%
ClassificationExperiment()

# %%
# loading sample dataset
from pycaret.datasets import get_data
data = get_data('juice')

# init setup
from pycaret.classification import ClassificationExperiment
s = ClassificationExperiment()
s.setup(data, target = 'Purchase', session_id = 123)

# model training and selection
best = s.compare_models()

# evaluate trained model
s.evaluate_model(best)

# predict on hold-out/test set
pred_holdout = s.predict_model(best)

# predict on new data
new_data = data.copy().drop('Purchase', axis = 1)
predictions = s.predict_model(best, data = new_data)
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# 0   0.000000   0.000000           0.24      1
# 1   0.150754   0.000000           0.24      1
# 2   0.000000   0.091398           0.23      1
# 3   0.000000   0.000000           0.00      1
# 4   0.000000   0.000000           0.00      0
# <style type="text/css">
# #T_8ddb4_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8ddb4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ddb4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8ddb4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ddb4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8ddb4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8ddb4_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8ddb4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8ddb4_row1_col1" class="data row1 col1" >Purchase</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8ddb4_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_8ddb4_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8ddb4_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_8ddb4_row3_col1" class="data row3 col1" >CH: 0, MM: 1</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8ddb4_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_8ddb4_row4_col1" class="data row4 col1" >(1070, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8ddb4_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_8ddb4_row5_col1" class="data row5 col1" >(1070, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8ddb4_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_8ddb4_row6_col1" class="data row6 col1" >(749, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8ddb4_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_8ddb4_row7_col1" class="data row7 col1" >(321, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8ddb4_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_8ddb4_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8ddb4_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_8ddb4_row9_col1" class="data row9 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8ddb4_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_8ddb4_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8ddb4_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_8ddb4_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8ddb4_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_8ddb4_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8ddb4_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_8ddb4_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8ddb4_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_8ddb4_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8ddb4_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_8ddb4_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8ddb4_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_8ddb4_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8ddb4_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_8ddb4_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8ddb4_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_8ddb4_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8ddb4_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_8ddb4_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_8ddb4_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_8ddb4_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_8ddb4_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_8ddb4_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_8ddb4_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_8ddb4_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb4_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_8ddb4_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_8ddb4_row23_col1" class="data row23 col1" >d026</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_429da th {
#   text-align: left;
# }
# #T_429da_row0_col0, #T_429da_row0_col4, #T_429da_row1_col0, #T_429da_row1_col1, #T_429da_row1_col2, #T_429da_row1_col3, #T_429da_row1_col5, #T_429da_row1_col6, #T_429da_row1_col7, #T_429da_row2_col0, #T_429da_row2_col1, #T_429da_row2_col2, #T_429da_row2_col3, #T_429da_row2_col4, #T_429da_row2_col5, #T_429da_row2_col6, #T_429da_row2_col7, #T_429da_row3_col0, #T_429da_row3_col1, #T_429da_row3_col2, #T_429da_row3_col3, #T_429da_row3_col4, #T_429da_row3_col5, #T_429da_row3_col6, #T_429da_row3_col7, #T_429da_row4_col0, #T_429da_row4_col1, #T_429da_row4_col2, #T_429da_row4_col3, #T_429da_row4_col4, #T_429da_row4_col5, #T_429da_row4_col6, #T_429da_row4_col7, #T_429da_row5_col0, #T_429da_row5_col1, #T_429da_row5_col2, #T_429da_row5_col3, #T_429da_row5_col4, #T_429da_row5_col5, #T_429da_row5_col6, #T_429da_row5_col7, #T_429da_row6_col0, #T_429da_row6_col1, #T_429da_row6_col2, #T_429da_row6_col3, #T_429da_row6_col4, #T_429da_row6_col5, #T_429da_row6_col6, #T_429da_row6_col7, #T_429da_row7_col0, #T_429da_row7_col1, #T_429da_row7_col2, #T_429da_row7_col3, #T_429da_row7_col4, #T_429da_row7_col5, #T_429da_row7_col6, #T_429da_row7_col7, #T_429da_row8_col0, #T_429da_row8_col1, #T_429da_row8_col2, #T_429da_row8_col3, #T_429da_row8_col4, #T_429da_row8_col5, #T_429da_row8_col6, #T_429da_row8_col7, #T_429da_row9_col0, #T_429da_row9_col1, #T_429da_row9_col2, #T_429da_row9_col3, #T_429da_row9_col4, #T_429da_row9_col5, #T_429da_row9_col6, #T_429da_row9_col7, #T_429da_row10_col0, #T_429da_row10_col1, #T_429da_row10_col2, #T_429da_row10_col3, #T_429da_row10_col4, #T_429da_row10_col5, #T_429da_row10_col6, #T_429da_row10_col7, #T_429da_row11_col0, #T_429da_row11_col1, #T_429da_row11_col2, #T_429da_row11_col3, #T_429da_row11_col4, #T_429da_row11_col5, #T_429da_row11_col6, #T_429da_row11_col7, #T_429da_row12_col0, #T_429da_row12_col1, #T_429da_row12_col2, #T_429da_row12_col3, #T_429da_row12_col4, #T_429da_row12_col5, #T_429da_row12_col6, #T_429da_row12_col7, #T_429da_row13_col0, #T_429da_row13_col1, #T_429da_row13_col2, #T_429da_row13_col3, #T_429da_row13_col4, #T_429da_row13_col5, #T_429da_row13_col6, #T_429da_row13_col7 {
#   text-align: left;
# }
# #T_429da_row0_col1, #T_429da_row0_col2, #T_429da_row0_col3, #T_429da_row0_col5, #T_429da_row0_col6, #T_429da_row0_col7, #T_429da_row1_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_429da_row0_col8, #T_429da_row1_col8, #T_429da_row2_col8, #T_429da_row3_col8, #T_429da_row4_col8, #T_429da_row5_col8, #T_429da_row6_col8, #T_429da_row7_col8, #T_429da_row8_col8, #T_429da_row10_col8, #T_429da_row11_col8, #T_429da_row12_col8, #T_429da_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_429da_row9_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_429da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_429da_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_429da_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_429da_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_429da_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_429da_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_429da_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_429da_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_429da_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_429da_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_429da_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_429da_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_429da_row0_col1" class="data row0 col1" >0.8278</td>
#       <td id="T_429da_row0_col2" class="data row0 col2" >0.8941</td>
#       <td id="T_429da_row0_col3" class="data row0 col3" >0.7637</td>
#       <td id="T_429da_row0_col4" class="data row0 col4" >0.7909</td>
#       <td id="T_429da_row0_col5" class="data row0 col5" >0.7740</td>
#       <td id="T_429da_row0_col6" class="data row0 col6" >0.6354</td>
#       <td id="T_429da_row0_col7" class="data row0 col7" >0.6388</td>
#       <td id="T_429da_row0_col8" class="data row0 col8" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_429da_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_429da_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_429da_row1_col1" class="data row1 col1" >0.8171</td>
#       <td id="T_429da_row1_col2" class="data row1 col2" >0.8932</td>
#       <td id="T_429da_row1_col3" class="data row1 col3" >0.7224</td>
#       <td id="T_429da_row1_col4" class="data row1 col4" >0.7952</td>
#       <td id="T_429da_row1_col5" class="data row1 col5" >0.7540</td>
#       <td id="T_429da_row1_col6" class="data row1 col6" >0.6094</td>
#       <td id="T_429da_row1_col7" class="data row1 col7" >0.6140</td>
#       <td id="T_429da_row1_col8" class="data row1 col8" >0.3370</td>
#     </tr>
#     <tr>
#       <th id="T_429da_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_429da_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_429da_row2_col1" class="data row2 col1" >0.8158</td>
#       <td id="T_429da_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_429da_row2_col3" class="data row2 col3" >0.7431</td>
#       <td id="T_429da_row2_col4" class="data row2 col4" >0.7807</td>
#       <td id="T_429da_row2_col5" class="data row2 col5" >0.7581</td>
#       <td id="T_429da_row2_col6" class="data row2 col6" >0.6099</td>
#       <td id="T_429da_row2_col7" class="data row2 col7" >0.6138</td>
#       <td id="T_429da_row2_col8" class="data row2 col8" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_429da_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_429da_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_429da_row3_col1" class="data row3 col1" >0.8037</td>
#       <td id="T_429da_row3_col2" class="data row3 col2" >0.8888</td>
#       <td id="T_429da_row3_col3" class="data row3 col3" >0.7499</td>
#       <td id="T_429da_row3_col4" class="data row3 col4" >0.7545</td>
#       <td id="T_429da_row3_col5" class="data row3 col5" >0.7476</td>
#       <td id="T_429da_row3_col6" class="data row3 col6" >0.5877</td>
#       <td id="T_429da_row3_col7" class="data row3 col7" >0.5926</td>
#       <td id="T_429da_row3_col8" class="data row3 col8" >0.0470</td>
#     </tr>
#     <tr>
#       <th id="T_429da_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_429da_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_429da_row4_col1" class="data row4 col1" >0.7930</td>
#       <td id="T_429da_row4_col2" class="data row4 col2" >0.8729</td>
#       <td id="T_429da_row4_col3" class="data row4 col3" >0.7257</td>
#       <td id="T_429da_row4_col4" class="data row4 col4" >0.7420</td>
#       <td id="T_429da_row4_col5" class="data row4 col5" >0.7317</td>
#       <td id="T_429da_row4_col6" class="data row4 col6" >0.5636</td>
#       <td id="T_429da_row4_col7" class="data row4 col7" >0.5658</td>
#       <td id="T_429da_row4_col8" class="data row4 col8" >0.0350</td>
#     </tr>
#     <tr>
#       <th id="T_429da_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_429da_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_429da_row5_col1" class="data row5 col1" >0.7917</td>
#       <td id="T_429da_row5_col2" class="data row5 col2" >0.8640</td>
#       <td id="T_429da_row5_col3" class="data row5 col3" >0.7018</td>
#       <td id="T_429da_row5_col4" class="data row5 col4" >0.7489</td>
#       <td id="T_429da_row5_col5" class="data row5 col5" >0.7225</td>
#       <td id="T_429da_row5_col6" class="data row5 col6" >0.5565</td>
#       <td id="T_429da_row5_col7" class="data row5 col7" >0.5592</td>
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# <style type="text/css">
# </style>
# <table id="T_9171a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9171a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9171a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9171a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9171a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9171a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9171a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9171a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9171a_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9171a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9171a_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_9171a_row0_col1" class="data row0 col1" >0.8380</td>
#       <td id="T_9171a_row0_col2" class="data row0 col2" >0.9073</td>
#       <td id="T_9171a_row0_col3" class="data row0 col3" >0.7680</td>
#       <td id="T_9171a_row0_col4" class="data row0 col4" >0.8067</td>
#       <td id="T_9171a_row0_col5" class="data row0 col5" >0.7869</td>
#       <td id="T_9171a_row0_col6" class="data row0 col6" >0.6564</td>
#       <td id="T_9171a_row0_col7" class="data row0 col7" >0.6569</td>
#     </tr>
#   </tbody>
# </table>

# %%
# !pip install git+https://github.com/StatMixedML/LightGBMLSS.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/StatMixedML/LightGBMLSS.git
#   Cloning https://github.com/StatMixedML/LightGBMLSS.git to /tmp/pip-req-build-_6fgdfx7
#   Running command git clone --filter=blob:none --quiet https://github.com/StatMixedML/LightGBMLSS.git /tmp/pip-req-build-_6fgdfx7
#   Resolved https://github.com/StatMixedML/LightGBMLSS.git to commit edeae7bec98459a0da7a5b7bda2b2a99424ceebf
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lightgbm~=3.3.5 in /usr/local/lib/python3.9/site-packages (from lightgbmlss==0.2.2) (3.3.5)
# Collecting torch~=2.0.1
#   Downloading torch-2.0.1-cp39-cp39-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 1.7 MB/s eta 0:00:0000:0100:05
# Collecting pyro-ppl~=1.8.5
#   Downloading pyro_ppl-1.8.5-py3-none-any.whl (732 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.5/732.5 kB 4.7 MB/s eta 0:00:00a 0:00:01
# Collecting optuna~=3.1.1
#   Downloading optuna-3.1.1-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Collecting properscoring~=0.1
#   Downloading properscoring-0.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: scikit-learn~=1.2.2 in /usr/local/lib/python3.9/site-packages (from lightgbmlss==0.2.2) (1.2.2)
# Collecting numpy~=1.24.3
#   Downloading numpy-1.24.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 4.6 MB/s eta 0:00:0000:0100:01
# Collecting pandas~=2.0.1
#   Downloading pandas-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 4.8 MB/s eta 0:00:0000:0100:01
# Collecting plotnine~=0.12.1
#   Downloading plotnine-0.12.1-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 1.5 MB/s eta 0:00:0000:0100:010m
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from lightgbmlss==0.2.2) (1.10.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/site-packages (from lightgbmlss==0.2.2) (4.65.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/site-packages (from lightgbmlss==0.2.2) (3.7.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/site-packages (from lightgbm~=3.3.5->lightgbmlss==0.2.2) (0.40.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/site-packages (from optuna~=3.1.1->lightgbmlss==0.2.2) (23.1)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.11.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting sqlalchemy>=1.3.0
#   Downloading SQLAlchemy-2.0.17-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 1.3 MB/s eta 0:00:0000:0100:010m
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting PyYAML
#   Downloading PyYAML-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.8/661.8 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/site-packages (from pandas~=2.0.1->lightgbmlss==0.2.2) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.9/site-packages (from pandas~=2.0.1->lightgbmlss==0.2.2) (2.8.2)
# Collecting mizani>=0.9.0
#   Downloading mizani-0.9.2-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 1.2 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.9/site-packages (from plotnine~=0.12.1->lightgbmlss==0.2.2) (0.5.3)
# Requirement already satisfied: statsmodels>=0.14.0 in /usr/local/lib/python3.9/site-packages (from plotnine~=0.12.1->lightgbmlss==0.2.2) (0.14.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib->lightgbmlss==0.2.2) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/site-packages (from matplotlib->lightgbmlss==0.2.2) (4.40.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/site-packages (from matplotlib->lightgbmlss==0.2.2) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/site-packages (from matplotlib->lightgbmlss==0.2.2) (3.1.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/site-packages (from matplotlib->lightgbmlss==0.2.2) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/site-packages (from matplotlib->lightgbmlss==0.2.2) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib->lightgbmlss==0.2.2) (1.1.0)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 1.5 MB/s eta 0:00:00-:--:--
# Collecting pyro-api>=0.1.1
#   Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/site-packages (from scikit-learn~=1.2.2->lightgbmlss==0.2.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn~=1.2.2->lightgbmlss==0.2.2) (3.1.0)
# Collecting nvidia-curand-cu11==10.2.10.91
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 3.7 MB/s eta 0:00:0000:0100:01m
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 11.0 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.3 MB/s eta 0:00:0000:0100:04
# Collecting nvidia-cuda-cupti-cu11==11.7.101
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 3.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusolver-cu11==11.4.0.1
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 3.6 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu11==11.7.4.91
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 4.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu11==11.7.91
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 7.2 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu11==2.14.3
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 1.9 MB/s eta 0:00:0000:0100:02
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/site-packages (from torch~=2.0.1->lightgbmlss==0.2.2) (4.6.3)
# Collecting nvidia-cufft-cu11==10.9.0.58
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 3.2 MB/s eta 0:00:0000:0100:02
# Collecting sympy
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 2.6 MB/s eta 0:00:0000:0100:01
# Collecting triton==2.0.0
#   Downloading triton-2.0.0-1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 1.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 2.7 MB/s eta 0:00:0000:0100:01
# Collecting networkx
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 4.8 MB/s eta 0:00:00a 0:00:01
# Collecting filelock
#   Downloading filelock-3.12.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/site-packages (from torch~=2.0.1->lightgbmlss==0.2.2) (3.1.2)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 1.4 MB/s eta 0:00:0000:0100:05
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch~=2.0.1->lightgbmlss==0.2.2) (67.8.0)
# Collecting cmake
#   Downloading cmake-3.26.4-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 2.8 MB/s eta 0:00:0000:0100:01
# Collecting lit
#   Downloading lit-16.0.6.tar.gz (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.7/153.7 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->lightgbmlss==0.2.2) (3.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/site-packages (from patsy>=0.5.1->plotnine~=0.12.1->lightgbmlss==0.2.2) (1.16.0)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (610 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 610.9/610.9 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/site-packages (from jinja2->torch~=2.0.1->lightgbmlss==0.2.2) (2.1.3)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 1.7 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: lightgbmlss, lit
#   Building wheel for lightgbmlss (setup.py) ... done
#   Created wheel for lightgbmlss: filename=lightgbmlss-0.2.2-py3-none-any.whl size=1383221 sha256=044abf3c1fca3d26e0c3ee0d87cb22a617bdcf8d872e3cf19e9ac55433757960
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ho5tgrxj/wheels/65/c2/c6/fea1bcc11b1d11656245f6a3be255dfd75cc77e2c88b2361ec
#   Building wheel for lit (pyproject.toml) ... done
#   Created wheel for lit: filename=lit-16.0.6-py3-none-any.whl size=93582 sha256=a2cebd0f4c338680f904b1fbb29c15c42f8e480bc596c8d38c4141a972d360f4
#   Stored in directory: /home/vscode/.cache/pip/wheels/a5/36/d6/cac2e6fb891889b33a548f2fddb8b4b7726399aaa2ed32b188
# Successfully built lightgbmlss lit
# Installing collected packages: pyro-api, mpmath, lit, cmake, tzdata, sympy, PyYAML, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, numpy, networkx, Mako, greenlet, filelock, colorlog, sqlalchemy, pandas, opt-einsum, nvidia-cusolver-cu11, nvidia-cudnn-cu11, cmaes, properscoring, alembic, optuna, mizani, plotnine, triton, torch, pyro-ppl, lightgbmlss
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sktime 0.17.0 requires pandas<2.0.0,>=1.1.0, but you have pandas 2.0.2 which is incompatible.
# pycaret 3.0.2 requires numpy<1.24,>=1.21, but you have numpy 1.24.4 which is incompatible.
# pycaret 3.0.2 requires pandas<2.0.0,>=1.3.0, but you have pandas 2.0.2 which is incompatible.
# plotly-resampler 0.8.3.2 requires pandas<2.0.0,>=1.3.5, but you have pandas 2.0.2 which is incompatible.
# Successfully installed Mako-1.2.4 PyYAML-6.0 alembic-1.11.1 cmaes-0.9.1 cmake-3.26.4 colorlog-6.7.0 filelock-3.12.2 greenlet-2.0.2 lightgbmlss-0.2.2 lit-16.0.6 mizani-0.9.2 mpmath-1.3.0 networkx-3.1 numpy-1.24.4 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 opt-einsum-3.3.0 optuna-3.1.1 pandas-2.0.2 plotnine-0.12.1 properscoring-0.1 pyro-api-0.1.2 pyro-ppl-1.8.5 sqlalchemy-2.0.17 sympy-1.12 torch-2.0.1 triton-2.0.0 tzdata-2023.3
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install git+https://github.com/dsgibbons/shap.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/dsgibbons/shap.git
#   Cloning https://github.com/dsgibbons/shap.git to /tmp/pip-req-build-_4utkjno
#   Running command git clone --filter=blob:none --quiet https://github.com/dsgibbons/shap.git /tmp/pip-req-build-_4utkjno
#   Resolved https://github.com/dsgibbons/shap.git to commit ae3adbeaf79e8b0c05aec205bdd34608fd87a33b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.9/site-packages (from shap==0.41.0) (4.65.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/site-packages (from shap==0.41.0) (0.57.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/site-packages (from shap==0.41.0) (2.2.1)
# Requirement already satisfied: numpy in /home/vscode/.local/lib/python3.9/site-packages (from shap==0.41.0) (1.24.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from shap==0.41.0) (1.10.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.9/site-packages (from shap==0.41.0) (23.1)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: pandas in /home/vscode/.local/lib/python3.9/site-packages (from shap==0.41.0) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/site-packages (from shap==0.41.0) (1.2.2)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /usr/local/lib/python3.9/site-packages (from numba->shap==0.41.0) (0.40.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/site-packages (from pandas->shap==0.41.0) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.9/site-packages (from pandas->shap==0.41.0) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/vscode/.local/lib/python3.9/site-packages (from pandas->shap==0.41.0) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn->shap==0.41.0) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/site-packages (from scikit-learn->shap==0.41.0) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->shap==0.41.0) (1.16.0)
# Building wheels for collected packages: shap
#   Building wheel for shap (pyproject.toml) ... done
#   Created wheel for shap: filename=shap-0.41.0-cp39-cp39-linux_x86_64.whl size=516453 sha256=724bea661f27b2e6a5eafcf058a66c4682bc0d56883bed79e0197b223531a8da
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xujf9t6b/wheels/84/2e/b3/0a2427ebcfbd952c045a8c60a30ba1cce5989e8e9162cfc18a
# Successfully built shap
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# create a lightgbmllsaaa
def lightgbmlls_setup()
